# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
cars1=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv')
cars2=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv')

cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1=cars1.drop(['Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13'],axis=1)

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print("No of observatin in cars1:",len(cars1))
print("No of observation is cars2:",len(cars2))
# Out:
# No of observatin in cars1: 198
# No of observation is cars2: 200

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars=cars1.join(cars2, how='left', lsuffix='_left', rsuffix='_right')

# %%
cars.shape
# Out:
# (198, 18)

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
owners=np.random.randint(15000, high=73000, size=198, dtype=int)
owners
# Out:
# array([26965, 32852, 27868, 65484, 19996, 30513, 70114, 17984, 18871,
#        27450, 66710, 40801, 70769, 44022, 26657, 35771, 67560, 37388,
#        70217, 59676, 64722, 61440, 33689, 51366, 21859, 66916, 63504,
#        62748, 16739, 24550, 36861, 40565, 71082, 30875, 24457, 33451,
#        44238, 43166, 22895, 57655, 23021, 72574, 60657, 52347, 26140,
#        21871, 18103, 68095, 40079, 53140, 23119, 62101, 33854, 31231,
#        29123, 29170, 16851, 35238, 40624, 51549, 20128, 45791, 25284,
#        18698, 29126, 50119, 18981, 71450, 62344, 72191, 39109, 26604,
#        65059, 16543, 38469, 59456, 61499, 17542, 22857, 16939, 37841,
#        25090, 47635, 15639, 23141, 61989, 53838, 38220, 62309, 67530,
#        60855, 62008, 64774, 40450, 38725, 49778, 59582, 49814, 62249,
#        19284, 43310, 49050, 19071, 18559, 58368, 18524, 50543, 27682,
#        23104, 18980, 67346, 19098, 35861, 23952, 53336, 67820, 71038,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners']=owners

# %%
cars
# Out:
#      mpg_left  cylinders_left  displacement_left horsepower_left  weight_left  \
# 0        18.0               8                307             130         3504
# 1        15.0               8                350             165         3693
# 2        18.0               8                318             150         3436
# 3        16.0               8                304             150         3433
# 4        17.0               8                302             140         3449
# ..        ...             ...                ...             ...          ...
# 193      24.0               6                200              81         3012
# 194      22.5               6                232              90         3085
# 195      29.0               4                 85              52         2035
# 196      24.5               4                 98              60         2164
# 197      29.0               4                 90              70         1937
#
# ...
